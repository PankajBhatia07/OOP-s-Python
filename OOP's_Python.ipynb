# %% [markdown]
# # ***OOP's Questions***

# %% [markdown]
# ##**Q1.What is Object-Oriented Programming (OOP)?**

# %% [markdown]
# Object-Oriented Programming (OOP) is a programming paradigm based on the concept of objects, which bundle data (attributes) and behavior (methods) together. It promotes code reusability, scalability, and organization.
#
# **Key Principles of OOP:**
#
# **1.Encapsulation**– Hides internal details and only exposes necessary parts.
#
# **2.Abstraction** – Focuses on essential features, hiding complexity.
#
# **3.Inheritance** – Allows one class to inherit properties and behavior from another.
#
# **4.Polymorphism** – Enables objects to take multiple forms, improving flexibility.

# %% [markdown]
# ## **Q2.What is a class in OOP?**

# %% [markdown]
# A class in Object-Oriented Programming (OOP) is a blueprint or template for creating objects. It defines the properties (attributes) and behaviors (methods) that the objects created from it will have.

# %% [markdown]
# ##**Q3.What is an object in OOP?**

# %% [markdown]
# An object is an instance of a class. It is a real-world entity that has attributes (data) and methods (behavior) defined by its class.

# %% [markdown]
# ##**Q4.What is the difference between abstraction and encapsulation?**

# %% [markdown]
# ![Screenshot 2025-03-04 110505.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q5.What are dunder methods in Python?**

# %% [markdown]
# Dunder (double underscore) methods, also known as magic methods or special methods, are predefined methods in Python that start and end with double underscores (e.g., __init__, __str__).
#
# They enable custom behavior for objects and are commonly used to define how objects interact with built-in Python operations like initialization, representation, arithmetic, and comparison.

# %% [markdown]
# **Common Dunder Methods and Their Use Cases**
# ![Screenshot 2025-03-04 111122.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q6.Explain the concept of inheritance in OOP.**

# %% [markdown]
# Inheritance is an OOP concept that allows one class (child/derived) to acquire the attributes and methods of another class (parent/base). It promotes code reusability, hierarchical relationships, and polymorphism.
#
# **Types of Inheritance**
#
# **1.Single Inheritance** – One child class inherits from one parent class.
#
# **2.Multiple Inheritance** – A child class inherits from multiple parent classes.
#
# **3.Multilevel Inheritance** – A class inherits from another derived class.
#
# **4.Hierarchical Inheritance** – Multiple child classes inherit from a single parent class.
#
# **5.Hybrid Inheritance** – A combination of multiple types of inheritance.

# %% [markdown]
# ## **Q7.What is polymorphism in OOP.**

# %% [markdown]
# Polymorphism is an Object-Oriented Programming (OOP) concept that allows objects of different classes to be treated as if they belong to the same class. It enables a single interface to be used for different data types, enhancing code flexibility and reusability.
#
# **Types of Polymorphism**
#
# **1.Method Overriding (Runtime Polymorphism)** – A child class provides a specific implementation of a method that is already defined in its parent class.
#
# **2.Method Overloading (Compile-time Polymorphism, Not in Python)** – A class has multiple methods with the same name but different parameters (not directly supported in Python).
#
# **3.Operator Overloading** – Allows operators like +, -, * to work differently based on the object type.

# %% [markdown]
# ## **Q8.How is encapsulation achieved in Python?**

# %% [markdown]
# Encapsulation is an Object-Oriented Programming (OOP) principle that restricts direct access to an object's data and allows controlled modification through methods.
#
# In Python, encapsulation is achieved using:
# * **Private Variables** (__variable) – Prevents
# direct access.
#
# * **Protected Variables** (_variable) – Indicates limited access (convention).
#
# * **Getter and Setter Methods**– Control read/write access.
#
# * **Property Decorators** (@property) – Provide elegant attribute control.

# %% [markdown]
# ## **Q9.What is a constructor in Python?**

# %% [markdown]
# A constructor in Python is a special method that automatically runs when an object is created. It is used to initialize an object's attributes.
#
# In Python, the constructor is defined using the __init__ method.

# %% [markdown]
# ## **Q10.What are class and static methods in Python?**

# %% [markdown]
# In Python, both class methods and static methods are used for handling behavior at the class level rather than at the instance level.
#
# **1. Class Method (@classmethod)**
# * Operates on the class itself, not on instances.
# * Uses cls as the first parameter.
# * Can access and modify class variables.
#
# **2. Static Method (@staticmethod)**
# * Does NOT operate on instance (self) or class (cls)
# * Acts as a utility function within a class
# * Can be called without creating an instance

# %% [markdown]
# ![Screenshot 2025-03-04 121223.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q11.What is method overloading in Python?**

# %% [markdown]
# Method Overloading allows multiple methods with the same name but different parameters in a class. However, Python does not support traditional method overloading like Java or C++. Instead, Python achieves it using default arguments or *args and **kwargs.

# %% [markdown]
# ## **Q12.What is method overriding in OOP?**

# %% [markdown]
# Method Overriding is an Object-Oriented Programming (OOP) concept where a child class provides a specific implementation of a method that is already defined in its parent class.
#
# * Same method name in both parent and child classes
# * Same parameters in both methods
# * Child class method overrides the parent class method

# %% [markdown]
# ## **Q13.What is a property decorator in Python?**

# %% [markdown]
# A property decorator (@property) in Python is used to define getter, setter, and deleter methods in a class, allowing controlled access to private attributes.
#
# * Encapsulates attributes
# * Allows attribute-like access instead of method calls
# * Provides validation and computed properties

# %% [markdown]
# ## **Q14.Why is polymorphism important in OOP?**

# %% [markdown]
# Polymorphism in Object-Oriented Programming (OOP) allows objects of different classes to be treated as objects of a common superclass. This is crucial for code flexibility, reusability, and maintainability.
#
# **1. Code Reusability**
#
# Polymorphism enables using the same interface for different data types, reducing redundant code.
#
# **2. Flexibility and Scalability**
#
# Polymorphism makes it easy to extend functionality without modifying existing code.
#
# **3. Easier Maintenance and Extensibility**
#
# With polymorphism, new features can be added without breaking existing functionality.

# %% [markdown]
# ## **Q15.What is an abstract class in Python?**

# %% [markdown]
# An abstract class in Python is a class that cannot be instantiated and must be inherited by a subclass. It provides a blueprint for other classes, enforcing the implementation of specific methods in derived classes.
#
# * Defined using ABC (Abstract Base Class)
# * Contains at least one abstract method (a method without implementation)
# * Forces subclasses to implement specific behaviors
#
# **1. Creating an Abstract Class in Python**
#
# Python’s abc module provides the ABC (Abstract Base Class) and the @abstractmethod decorator.
#
# **2. Abstract Class with Concrete Methods**
#
# An abstract class can also have concrete (regular) methods.

# %% [markdown]
# ## **Q16.What are the advantages of OOP?**

# %% [markdown]
# Object-Oriented Programming (OOP) provides a structured approach to software development, making it modular, reusable, and scalable. Here are its key benefits:
#
# **1. Modularity (Encapsulation)**
# * Encapsulation allows bundling of data and methods into a single unit (class).
# * Protects data from unintended modification using private/protected attributes.
#
# **2. Code Reusability (Inheritance)**
#
# * Inheritance allows one class to derive properties from another.
# * Reduces redundancy and improves maintainability.
#
# **3. Flexibility and Scalability (Polymorphism)**
# * Polymorphism allows a single method name to be used in multiple forms.
# *  Improves code flexibility by handling different objects through a common interface.
#
# **4. Easy Maintenance and Upgrades**
#
# * OOP makes it easier to modify and extend existing code without affecting other parts.
# * Changes in one class do not break dependent code.
#
# **5. Real-World Modeling**
# * OOP models real-world entities like Car, Employee, BankAccount, etc.
# * Improves problem-solving by organizing data and behavior logically.
#
# **6. Security through Abstraction**
#
# * Abstraction hides unnecessary details from the user and exposes only essential functionalities.
# * Prevents direct access to sensitive data, ensuring security.

# %% [markdown]
# ![Screenshot 2025-03-04 123352.png](data:image/png;base64,...)

# %% [markdown]
#  ## **Q17.What is the difference between a class variable and an instance variable?**

# %% [markdown]
# In Python, class variables and instance variables are used to store data within a class, but they have different scopes and behaviors.
#
# ![Screenshot 2025-03-04 123837.png](data:image/png;base64,...)

# %% [markdown]
# **Key Differences**
#
# ![Screenshot 2025-03-04 124115.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q18.What is multiple inheritance in Python?**

# %% [markdown]
# Multiple inheritance is a feature in Python where a class can inherit from more than one parent class. This allows a subclass to inherit attributes and methods from multiple sources.
#
# * Enables code reusability from multiple classes.
# * Allows a class to combine functionalities from different classes.
# * Can lead to complexity due to the diamond problem (resolved using the Method Resolution Order (MRO)).

# %% [markdown]
# ## **Q19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?**

# %% [markdown]
# ______str__ and ______repr__ are dunder (double underscore) methods used for string representation of objects in Python, but they serve different purposes:
#
# 1.______str__ (User-Friendly Representation)
#
# * Returns a readable and informal string representation of an object.
#
# * Meant for end-users.
#
# * Used when calling print(object) or str(object).
#
# 2.______repr__  (Developer-Friendly Representation)
#
# * Returns an unambiguous and formal representation.
#
# * Meant for developers and debugging.
#
# * Should ideally return a string that can recreate the object using eval(repr(object)).
#
# * Used when calling repr(object) or in interactive mode.

# %% [markdown]
# ## **Q20.What is the significance of the ‘super()’ function in Python?**

# %% [markdown]
# The super() function in Python is used to call methods from a parent (super) class inside a child (sub) class. It allows for code reuse, method resolution, and multiple inheritance support.
#
# **Key Benefits of super()**
#
# **1.Access Parent Class Methods**
#
# * Calls methods from the parent class without explicitly naming it.
#
# **2.Supports Multiple Inheritance**
#
# * Works with Method Resolution Order (MRO) to determine the correct method call order.
#
# **3.Avoids Redundant Code**
#
# * Prevents rewriting parent class methods in child classes.
#
# **4.Dynamically Resolves the Parent Class**
#
# * Makes code more maintainable and flexible.

# %% [markdown]
# ## **Q21.What is the significance of the _ _del_ _ method in Python**

# %% [markdown]
# The _ _del_ _ method in Python is a destructor that is automatically called when an object is about to be destroyed (garbage collected). It is used to clean up resources, such as closing files or releasing memory.
#
# **Key Points About _ _del_ _**
#
# * Called when an object is deleted or goes out of scope.
# * Used for cleanup operations like closing database connections, files, or network sockets.
# * Not always predictable since Python's garbage collection may delay object destruction.
# * Avoid using it excessively as it may cause unintended side effects.

# %% [markdown]
# ## **Q22.What is the difference between @staticmethod and @classmethod in Python?**

# %% [markdown]
# Both @staticmethod and @classmethod are decorators used to define special types of methods in a class. However, they have different behaviors and use cases.
#
# ![Screenshot 2025-03-04 130200.png](data:image/png;base64,...)

# %% [markdown]
#  ## **Q23.How does polymorphism work in Python with inheritance?**

# %% [markdown]
# Polymorphism in Python allows different classes to have methods with the same name, enabling a common interface for different data types. When combined with inheritance, it enables subclasses to override or extend parent class methods while maintaining the same method signature.
#
# **How It Works:**
#
# **1.Method Overriding**
#
# * A subclass redefines a method from the parent class with its own implementation.
#
# * Ensures that calling the method on a subclass instance executes the overridden version.
#
# **2.Dynamic Method Resolution**
#
# * Python determines at runtime which method to call based on the object type.
#
# * This allows different classes to be treated uniformly via a common interface.
#
# **Benefits:**
# * Provides flexibility and code reusability.
# * Enables different behaviors for the same method name.
# * Supports object-oriented design principles like abstraction.

# %% [markdown]
# ## **Q24.What is method chaining in Python OOP?**

# %% [markdown]
# Method chaining is a technique in Object-Oriented Programming (OOP) where multiple methods are called on the same object in a single statement. It works by making each method return **self** (the instance itself), allowing further method calls.
#
# **Key Benefits of Method Chaining**
# * Improves readability by reducing repeated object references.
# * Enables a fluent interface for cleaner, more expressive code.
# * Reduces temporary variables and keeps code concise.
#
# **How It Works:**
# * Each method modifies the object and returns self, allowing another method to be chained.

# %% [markdown]
# ## **Q25.What is the purpose of the __call__ method in Python?**

# %% [markdown]
# The _ _call_  _ method in Python allows an instance of a class to be called like a function. When an object has _ _call_ _ defined, using object() automatically invokes this method.
#
# **Benefits:**
# * Makes objects behave like functions, enabling a more intuitive API.
# * Allows customization of function-like behavior while maintaining state.
# * Useful for decorators, caching, and function wrappers.

# %% [markdown]
# # ***Practical Question***

# %% [markdown]
#  ## **Q1.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".**

# %%
#Parent class
class Animal:
  def speak(self):
    print("This animal makes a sound.")

class Dog(Animal):
  def speak(self):
    print("Bark!")

#usage
animal = Animal()
animal.speak()

dog = Dog()
dog.speak()
# Out:
# This animal makes a sound.
# Bark!

# %% [markdown]
# ## **Q2.Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.**

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

class Circle(Shape):
  def __init__(self,radius):
    self.radius = radius

  def area(self):
      return math.pi * self.radius ** 2

class Rectangle(Shape):
  def __init__(self,width,height):
     self.width = width
     self.height =height

  def area(self):
    return self.width * self.height

circle = Circle(5)
print("Circle Area:", circle.area())

rectangle = Rectangle(4,6)
print("Rectangle Area:", rectangle.area())
# Out:
# Circle Area: 78.53981633974483
# Rectangle Area: 24

# %% [markdown]
# ## **Q3.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.**

# %%
class Vehicle:
  def __init__(self, vehicle_type):
    self.vehicle_type = vehicle_type

  def display_type(self):
    print(f"Vehicle Type: {self.vehicle_type}")

class Car(Vehicle):
  def __init__(self,brand,model,vehicle_type="Car"):
    super().__init__(vehicle_type)
    self.brand = brand
    self.model = model

  def display_car(self):
    print(f"car brand: {self.brand}, Model: {self.model}")

class ElectricCar(Car):
  def __init__(self, brand, model, battery_capacity):
    super().__init__(brand, model)
    self.battery_capacity = battery_capacity

  def display_electric_type(self):
    self.display_type()
    self.display_car()
    print(f"Battery Capacity:{self.battery_capacity} kwh")

ecar = ElectricCar("Tesla","Model S",100)
ecar.display_electric_type()
# Out:
# Vehicle Type: Car
# car brand: Tesla, Model: Model S
# Battery Capacity:100 kwh

# %% [markdown]
# ## **Q4.Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.**

# %%
class Bird:
  def fly(self):
    print("Some birds can fly.")

class Sparrow(Bird):
  def fly(self):
    print("Sparrow files high in the sky!")

class Penguin(Bird):
  def fly(self):
    print("Penguins can't fly, but they swim!")

# Function deonstrating polymorphism
def bird_fly_test(bird):
    bird.fly()

sparrow = Sparrow()
penguin = Penguin()


bird_fly_test(sparrow)
bird_fly_test(penguin)
# Out:
# Sparrow files high in the sky!
# Penguins can't fly, but they swim!

# %% [markdown]
# ## **Q5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.**

# %%
class BankAccount:
  def __init__(self, initial_balance=0):
    self.__balance = initial_balance #private attribute

  def deposit(self, amount):
    if amount > 0:
      self.__balance += amount
      print(f"Deposited ${amount}")
    else:
      print("Deposit amount must be positive.")

  def withdraw(self, amount):
    if 0 < amount <= self.__balance:
      self.__balance -= amount
      print(f"Withdrawn: ${amount}")

    else:
      print("Insufficient balance or invalid amount.")

    def check_balance(self):
      print(f"Current Balance:${self.__balance}")


  account = BankAccount(100)
  account.deposit(50)
  account.withdraw(30)
  account.check_balance()
# Out:
# Deposited: $50
# Withdrawn: $30
# Current Balance: $120

# %% [markdown]
# ## **Q6.Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().**

# %%
class Instrument:
  def play(self):
    print("Playing an Instrument.")

class Guitar(Instrument):
  def play(self):
    print("Strumming the guitar!")

class Piano(Instrument):
  def play(self):
    print("Playing the paiano Keys!")


def play_instrument(instrument):
  instrument.play()

guitar = Guitar()
piano = Piano()

play_instrument(guitar)
play_instrument(piano)
# Out:
# Strumming the guitar!
# Playing the paiano Keys!

# %% [markdown]
# ## **Q7.Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.**

# %%
class MathOperations:
  @classmethod
  def add_numbers(cls, a, b):
    return a + b

  @staticmethod
  def subtract_numbers(a, b):
    return a - b

print("Addition", MathOperations.add_numbers(5,3))
print("Subtraction",MathOperations.subtract_numbers(10,4))
# Out:
# Addition 8
# Subtraction 6

# %% [markdown]
# ## **Q8.Implement a class Person with a class method to count the total number of persons created.**

# %%
class Person:
  count = 0

  def __init__(self,name):
    self.name = name
    Person.count +=1

  @classmethod
  def total_persons(cls):
      return cls.count

p1 = Person("Pankaj")
p2 = Person("Raman")
p3 = Person("Rajat")


print("Total Persons Created:",Person.total_persons())
# Out:
# Total Persons Created: 3

# %% [markdown]
# ## **Q9.Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".**

# %%
class Fraction:
  def __init__(self,numerator, denominator):
    if denominator == 0:
      raise ValueError("Denominator cananot be zero.")
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

fraction1 = Fraction(3, 4)
fraction2 = Fraction(5, 8)

print(fraction1)
print(fraction2)
# Out:
# 3/4
# 5/8

# %% [markdown]
# ## **Q10.Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors**

# %%
class Vector:
  def __init__(self,x,y):
    self.x = x
    self.y = y

  def __add__(self, other):
    if isinstance(other,Vector):
      return Vector(self.x + other.x, self.y + other.y)
    raise TypeError("Addition is only supported between two Vector objects.")

  def __str__(self):
    return f"({self.x},{self.y})"

v1 = Vector(2,3)
v2 = Vector(4,5)

result = v1 + v2
print("Resultant Vector:", result)
# Out:
# Resultant Vector: (6,8)

# %% [markdown]
# ## **Q11.Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."**

# %%
class Person:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person1 = Person("Pankaj", 23)
person2 = Person("Rajat", 22)

person1.greet()
person2.greet()
# Out:
# Hello, my name is Pankaj and I am 23 years old.
# Hello, my name is Rajat and I am 22 years old.

# %% [markdown]
#  ## **Q12.Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.**

# %%
class Student:
  def __init__(self,name,grades):
    self.name = name
    self.grades = grades

  def average_grade(self):
    if not self.grades:
      return 0
    else:
      return sum(self.grades)/len(self.grades)


student1 = Student("Pankaj",[67,89,90,78])
student2 = Student("Rajat",[56,91,77,72])

print(f"{student1.name}'s Average Grade: {student1.average_grade():.2f}")  #Output=86.25
print(f"{student2.name}'s Average Grade: {student2.average_grade():.2f}")
# Out:
# Pankaj's Average Grade: 81.00
# Rajat's Average Grade: 74.00

# %% [markdown]
# ## **Q13.Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.**

# %%
class Rectangle:
  def __init__(self,width=0,height=0):
    self.width = width
    self.height = height

  def set_dimensions(self,width, height):
    self.width = width
    self.height = height

  def area(self):
    return self.width * self.height

rect = Rectangle()
rect.set_dimensions(5,10)
print("Rectangle Area:", rect.area())
# Out:
# Rectangle Area: 50

# %% [markdown]
# ## **Q14.Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.**

# %%
class Employee:
  def __init__(self,name,hours_worked,hourly_rate):
    self.name = name
    self.hours_worked = hours_worked
    self.hourly_rate = hourly_rate


  def calculate_salary(self):
    return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self,name,hours_worked,hourly_rate,bonus):
      super(). __init__(name,hours_worked,hourly_rate)
      self.bonus = bonus

    def calculate_salary(self):
      base_salary = super().calculate_salary()
      return base_salary +self.bonus

emp = Employee("John", 40, 20)
mgr = Manager("Alice", 40, 30, 500)

print(f"{emp.name}'s Salary: ${emp.calculate_salary()}")  # Output: John's Salary: $800
print(f"{mgr.name}'s Salary: ${mgr.calculate_salary()}")
# Out:
# John's Salary: $800
# Alice's Salary: $1700

# %% [markdown]
# ## **Q15.Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.**

# %%
class Product:
  def __init__(self,name,price,quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity

product1 = Product("Laptop", 1200, 2)
product2 = Product("Headphones",150,4)

print(f"Total price of {product1.name}: ${product1.total_price()}")  # Output: $2400
print(f"Total price of {product2.name}: ${product2.total_price()}")
# Out:
# Total price of Laptop: $2400
# Total price of Headphones: $600

# %% [markdown]
#  ## **Q16.Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.**

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass

class Cow(Animal):
  def sound(self):
    return "Moo!"

class Sheep(Animal):
  def sound(self):
    return "Baaa!"

cow = Cow()
sheep = Sheep()

print(f"Cow:{cow.sound()}")
print(f"sheep:{sheep.sound()}")
# Out:
# Cow:Moo!
# sheep:Baaa!

# %% [markdown]
#  ## **Q17.Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.**

# %%
class Book:
  def __init__(self,title,author,year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
    return f"'{self.title}' by {self.author}, published in {self.year_published}."

book1 = Book("To kill a Mockingbird","Harper Lee",1960)
book2 = Book("1984","George Orwell",1949)

print(book1.get_book_info())
print(book2.get_book_info())
# Out:
# 'To kill a Mockingbird' by Harper Lee, published in 1960.
# '1984' by George Orwell, published in 1949.

# %% [markdown]
# ## **Q18.Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.**

# %%
class House:
  def __init__(self,address,price):
    self.address = address
    self.price = price

  def get_info(self):
    return f"House at {self.address}, priced at ${self.price}."

class Mansion(House):
  def __init__(self,address,price,number_of_rooms):
    super().__init__(address,price)
    self.number_of_rooms = number_of_rooms

  def get_info(self):
    return f"Mansion at {self.address}, priced at ${self.price}, with {self.number_of_rooms} rooms."


house = House("12 Nanaku House ", 2300000)
mansion = Mansion("34  Bhatia's Ave", 5000000,5)

print(house.get_info())
print(mansion.get_info())
# Out:
# House at 12 Nanaku House , priced at $2300000.
# Mansion at 34  Bhatia's Ave, priced at $5000000, with 5 rooms.
